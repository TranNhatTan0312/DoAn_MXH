# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

# %%
import pandas as pd
from pandas.core.frame import DataFrame
dataframe = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/khungbo/terrorism-in-turkey.csv', usecols=['city', 'Target_type'])

dataframe
# Out:
#                      city          Target_type
# 0                 Trabzon              Unknown
# 1                Istanbul               Police
# 2                Istanbul             Tourists
# 3                  Ankara                  NGO
# 4               Kucukmece             Business
# ..                    ...                  ...
# 542               Unknown             Military
# 543              Istanbul  Journalists & Media
# 544  Dogubeyazit district       Transportation
# 545     Semdinli district             Military
# 546              Istanbul             Business
#
# [547 rows x 2 columns]

# %%
#Tìm missing values
features_na = [features for features in dataframe.columns if dataframe[features].isnull().sum() > 0]
for feature in features_na:
    print(feature, np.round(dataframe[feature].isnull().mean(), 4),  ' % missing values')
else:
    print("No missing value found")
#--------------------------------------


df = dataframe.replace('NaN', np.nan)
#df= df.replace('Unknown', np.nan)
df.dropna(inplace=True)
df.drop_duplicates()
df.reset_index(drop=True,inplace=True)
df.head(18)
# Out:
# No missing value found
#                   city                  Target_type
# 0              Trabzon                      Unknown
# 1             Istanbul                       Police
# 2             Istanbul                     Tourists
# 3               Ankara                          NGO
# 4            Kucukmece                     Business
# 5             Yesilkoy               Transportation
# 6             Istanbul      Violent Political Party
# 7               Akdana  Private Citizens & Property
# 8             Istanbul                       Police
# 9              Unknown                       Police
# 10              Baykoy  Private Citizens & Property
# 11              Ankara          Airports & Aircraft
# 12   Resadiye District                     Business
# 13            Istanbul         Government (General)
# 14            Dikbiyik                     Business
# 15             Kizilsu                       Police
# 16            Istanbul                     Business
# 17  Yuksekova district                     Military

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   city         547 non-null    object
#  1   Target_type  547 non-null    object
# dtypes: object(2)
# memory usage: 8.7+ KB

# %%
df.describe()
# Out:
#             city           Target_type
# count        547                   547
# unique       165                    19
# top     Istanbul  Government (General)
# freq         175                    99

# %%
import networkx as nx
from networkx.algorithms import bipartite

B = nx.Graph()
City = df['city']
Target = df['Target_type']

#Name = df['UA_Country']
#Rating = df['Cost of Living']



print('Số thành phố:', City.nunique())
print('Số mục tiêu tấn công:', Target.nunique())
print('Số cạnh:', len(df))
# Out:
# Số thành phố: 165
# Số mục tiêu tấn công: 19
# Số cạnh: 547

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   city         547 non-null    object
#  1   Target_type  547 non-null    object
# dtypes: object(2)
# memory usage: 8.7+ KB

# %% [markdown]
# ## Tạo node

# %%
for index, row in df.iterrows():
    B.add_edge(row['city'], row['Target_type'], weight = 1)
    B.add_nodes_from(City, bipartite = 0)
    B.add_nodes_from(Target, bipartite = 1)

# %% [markdown]
# ## Code hiển thị đồ thị 2 phía

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
pos = nx.spring_layout(B)
fig, ax = plt.subplots(1, 1, figsize=(8,8), dpi=150)
nx.draw_networkx(B, pos = nx.drawing.layout.bipartite_layout(B, City), font_size=8, width=0.4)

# %% [markdown]
# ## Code hiển thị đồ thị 1 phía:

# %%
G = bipartite.weighted_projected_graph(B, City)
plt.figure(figsize=(12,17))
layout = nx.spring_layout(B, k=1)
nx.draw_networkx_nodes(B, layout, nodelist=City, node_size=150, node_color='red')
nx.draw_networkx_edges(B, layout, edge_color='#cccccc')
node_labels = dict(zip(City, City))
nx.draw_networkx_labels(B, layout, labels=node_labels)
plt.axis('off')
plt.title("Graph City")
plt.show()

# %% [markdown]
# ## Xuất dữ liệu để thao tác trên Gephi:

# %%
labels = nx.get_edge_attributes(B, 'weight')
df2 = pd.DataFrame(columns=['source', 'target', 'weight'])
for key, value in labels.items():
  df2 = df2.append({'source': key[0], 'target': key[1], 'weight': value}, ignore_index=True)
df2.to_csv(r'myTerrorismdataNodes.csv', index = False, header = True)

# %%
dfn = pd.read_csv('myTerrorismdataNodes.csv', usecols=['source', 'target'])
dfn.dropna()
dfn.drop_duplicates()
dfn
# Out:
#              source                       target
# 0           Trabzon                      Unknown
# 1           Unknown                       Police
# 2           Unknown                     Business
# 3           Unknown                        Hatay
# 4           Unknown                      Unknown
# ..              ...                          ...
# 257    Sur district  Private Citizens & Property
# 258            Hani         Government (General)
# 259            Hani                     Military
# 260           Ozalp  Private Citizens & Property
# 261  Derik district         Government (General)
#
# [262 rows x 2 columns]

# %%
G = nx.Graph()

edges = dfn[['source', 'target']]
G = nx.from_pandas_edgelist(edges, 'source', 'target')

print('Số đỉnh của đồ thị là', len(G.nodes()))
print('Số cạnh của đồ thị là', len(G.edges()))
# Out:
# Số đỉnh của đồ thị là 183
# Số cạnh của đồ thị là 262

# %%
print('Kiểm tra đồ thị liên thông: ')
nx.is_connected(G)
# Out:
# Kiểm tra đồ thị liên thông:
# True

# %%
# %load_ext autotime
# nx.draw_networkx(G)

pd.set_option('precision',10)

nodes = G.nodes()
degree = G.degree()
colors = [degree[n] for n in nodes]

pos = nx.kamada_kawai_layout(G)

cmap = plt.cm.viridis_r
cmap = plt.cm.Greys

vmin = min(colors)
vmax = max(colors)

fig = plt.figure(figsize = (5,5), dpi=100)

nx.draw(G,pos,alpha = 0.8, nodelist = nodes, node_color = 'w', node_size = 20, with_labels= False,font_size = 6, width = 0.2, cmap = cmap, edge_color ='yellow')
fig.set_facecolor('#0B243B')

plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %% [markdown]
# # New Sectiona

# %%
nx.average_shortest_path_length(G)
# Out:
# 3.299045217078004

# %%
# average degree

average_degree = sum([len(list(G.neighbors(n))) for n in G.nodes()]) / len(G.nodes())

print('Average degree: ', average_degree)
# Out:
# Average degree:  2.8579234972677594

# %%
#degree of each node
def print_table(data, columns):
  df = pd.DataFrame(data, columns=columns)
  return df

degree_dict = { node: 0 for node in G.nodes() }

for node in G.nodes():
  degree_dict[node] = len(list(G.neighbors(node)))

degree_df = print_table(degree_dict.items(), ['Node', 'Degree'])

degree_df
# Out:
#                Node  Degree
# 0           Trabzon       1
# 1           Unknown      15
# 2            Police      32
# 3          Business      35
# 4             Hatay       2
# ..              ...     ...
# 178         Pozanti       1
# 179    Sur district       1
# 180            Hani       2
# 181           Ozalp       1
# 182  Derik district       1
#
# [183 rows x 2 columns]

# %%
import community.community_louvain as community_louvain
import matplotlib.cm as cm
import matplotlib

plt.figure(figsize=(17, 12))
#compute the best partition
partition = community_louvain.best_partition(G)
#color the nodes according to their partition
cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
nx.draw_networkx_nodes(G, pos, partition.keys(), node_size=150, cmap=cmap, node_color=list(partition.values()))
nx.draw_networkx_edges(G, pos, alpha=0.5)
nx.draw_networkx_labels(G, pos)

plt.show()

# %%
import numpy as np
values = list(partition.values())

print('Số lượng cộng đồng: ', len(np.unique(values)))
# Out:
# Số lượng cộng đồng:  5

# %%
for i in range(len(np.unique(values))):
  print('Nhóm ', i, ":")
  for name, k in partition.items():
    if k == i:
      print(name)
  print("")
# Out:
# Nhóm  0 :
# Yuksekova district
# Seyhan District
# Yuksekova District
# Karakocan district
# Cizre District
# Cayirli
# Bulanik
# Catak
# Tunceli
# Dazya
# Tokat
# Nusaybin
# Pervari
# Guclukonak District
# Yuksekova
# Omerli
# Ziyaret
# Hozat district
# Torul
# Kocakoy
# Bukardi
# Geyiksuyu
# Dicle
# Siran
# Genc
# Kigi
# Semdinli district
# Genc district
# Cukurca district
# Cukurca
# Dogubeyazit district
# Bitlis
# Omurlu
# Mezra
# Nazimiye district
# Iskenderun
# Lice district
# Hani district
# Saray
# Diyadin
# Lice
# Malazgirt
# Caldiran district
# Akcay
#
# Nhóm  1 :
# Van
# Uskudar
# Bursa
# Batman
# Cankiri
# Hatay
# Mus
# Of
# Bingol
# Hakkari
# Yenimahalle District
# Cat district
# Konya
# Kiziltepe District
# Dogansar District
# Konak District
# Toroslar
# Erzin
# Gaziantep
# Pulumur
# Servi
# Alacakaya
# Beytussebap
# Beldeler
# Marmaris
# Buca district
# Saricam District
# Sanliurfa
# Nusaybin district
# Hizan district
# Reyhanli
# Hani
# Derik district
#
# Nhóm  2 :
# Yesilkoy
# Kirikkale
# Diyarbakir
# Uzumlu
# Semdinli
# Islahiye district
# Bakacak
# Sason
# Egirmec
# Silopi
# Duzici district
# Erzincan
# Gecitli
# Izmit
# Ercis
#
# Nhóm  3 :
# Kucukmece
# Akdana
# Baykoy
# Resadiye District
# Dikbiyik
# Elazig
# Adana
# Payas
# Caglayan
# Arabaslik
# Solhan
# Cigdemli
# Mesepinar
# Bademli
# Aydin
# Izmir
# Eskisehir
# Yenikoy
# Dortyol
# Mersin
# Yenisehir
# Gebze district
# Sirnak
# Antalya
# Pendik
# Malatya
# Ogulveren
# Refahiye
# Besikduzu
# Silvan
# Karliova
# Kemer
# Kasimli
# Celtiksuyu
# Kozluk
# Tatvan
# Antakya
# Belenoluk
# Suruc
# Sur district
# Ozalp
#
# Nhóm  4 :
# Trabzon
# Istanbul
# Ankara
# Unknown
# Kizilsu
# Marcik
# Diyadin District
# Isparta
# Kadikoy district
# Mardinkapi
# Taskoy
# Cesme
# Kusadasi district
# Ordu
# Gecitalan
# Samsun
# Diyarbakir district
# Kulp district
# Daglica
# Kabala
# Midyat
# Magara
# Cizre
# Cizre district
# Pinarbasi
# Beytussebap district
# Sultangazi district
# Aritis
# Ceylanpinar
# Ercis district
# Cinar
# Pozanti
# Military
# Government (General)
# Private Citizens & Property
# Transportation
# Religious Figures/Institutions
# Utilities
# Business
# Police
# Educational Institution
# NGO
# Government (Diplomatic)
# Journalists & Media
# Airports & Aircraft

# %%
from sklearn import preprocessing
from sklearn.cluster import KMeans
k = preprocessing.LabelEncoder()
dfkmean = df.copy()
dfkmean
# Out:
#                      city          Target_type
# 0                 Trabzon              Unknown
# 1                Istanbul               Police
# 2                Istanbul             Tourists
# 3                  Ankara                  NGO
# 4               Kucukmece             Business
# ..                    ...                  ...
# 542               Unknown             Military
# 543              Istanbul  Journalists & Media
# 544  Dogubeyazit district       Transportation
# 545     Semdinli district             Military
# 546              Istanbul             Business
#
# [547 rows x 2 columns]

# %%
k.fit(dfkmean['city'])
dfkmean['cityNum'] = k.transform(dfkmean['city'])
dfkmean['cityNum'].drop_duplicates()
# Out:
# 0      151
# 1       78
# 3        4
# 4       95
# 5      160
#       ...
# 498    124
# 501    144
# 506     70
# 528    119
# 530     43
# Name: cityNum, Length: 165, dtype: int64

# %%
k.fit(dfkmean['Target_type'])
dfkmean['TargetNum'] = k.transform(dfkmean['Target_type'])
dfkmean['TargetNum'].drop_duplicates()
# Out:
# 0      16
# 1      10
# 2      14
# 3       9
# 4       2
# 5      15
# 6      18
# 7      11
# 11      1
# 13      6
# 17      8
# 51     17
# 99      4
# 107     3
# 112     7
# 131    13
# 185     5
# 193    12
# 262     0
# Name: TargetNum, dtype: int64

# %%
import numpy as np
from sklearn.cluster import KMeans

sum_of_squared_distances = []
K = range(1, 10)
for num_clusters in K:
  kmeans = KMeans(n_clusters = num_clusters)
  kmeans.fit(dfkmean[['cityNum', 'TargetNum']])
  sum_of_squared_distances.append(kmeans.inertia_)
plt.plot(K, sum_of_squared_distances, 'bx-')
plt.xlabel('Values of K')
plt.ylabel( 'Sum of squared distances/Inertia')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
algorithm = KMeans(n_clusters = 2, init='random' )
algorithm.fit(dfkmean[['cityNum','TargetNum']])
labels2 = algorithm.labels_
centroids2 = algorithm.cluster_centers_ #Gán toạ độ trung tâm cụm
plt.clf()
plt.scatter( x = 'cityNum' ,y = 'TargetNum' , data = dfkmean[['cityNum','TargetNum']], c = labels2, s = 100 )
plt.scatter(x = centroids2[: , 0], y =  centroids2[: , 1], s = 100, c = 'red', alpha = 0.5)
plt.ylabel('city'), plt.xlabel('Target_type')
plt.show()
print('Toạ độ trung tâm cụm: ', centroids2)
# Out:
# Toạ độ trung tâm cụm:  [[136.73717949   8.73076923]
#  [ 56.46803069   7.57033248]]

# %%
note = dfkmean.drop_duplicates(subset='Target_type', keep="last")
print('Số mục tiêu tấn công: ',len(note[['Target_type','TargetNum']]))
print(note[['Target_type','TargetNum']].to_string())
# Out:
# Số mục tiêu tấn công:  19
#                                                     Target_type  TargetNum
# 47                                      Violent Political Party         18
# 99                                         Food or Water Supply          4
# 131                                           Telecommunication         13
# 208                                                     Unknown         16
# 236                                                    Tourists         14
# 262   police suspect ties to the Kurdistan Workers Party (PKK).          0
# 294                                                         NGO          9
# 455                              Religious Figures/Institutions         12
# 474                                                   Utilities         17
# 479                                     Educational Institution          3
# 511                                         Airports & Aircraft          1
# 529                                 Private Citizens & Property         11
# 532                                        Government (General)          6
# 536                                     Government (Diplomatic)          5
# 540                                                      Police         10
# 543                                         Journalists & Media          7
# 544                                              Transportation         15
# 545                                                    Military          8
# 546                                                    Business          2

# %%
noteGenre = dfkmean.drop_duplicates(subset='city', keep="last")
print('Số thành phố: ',len(noteGenre[['city','cityNum']]))
print(noteGenre[['city','cityNum']].to_string())
# Out:
# Số thành phố:  165
#                      city  cityNum
# 0                 Trabzon      151
# 4               Kucukmece       95
# 5                Yesilkoy      160
# 7                  Akdana        2
# 10                 Baykoy       13
# 12      Resadiye District      127
# 14               Dikbiyik       45
# 15                Kizilsu       89
# 22                  Bursa       24
# 23        Seyhan District      137
# 31                Cankiri       27
# 58                     Of      114
# 59                 Marcik      103
# 62   Yenimahalle District      158
# 65     Yuksekova District      162
# 66           Cat district       28
# 69       Diyadin District       47
# 70                  Konya       93
# 71     Kiziltepe District       90
# 72                 Elazig       55
# 73         Cizre District       37
# 78                 Uzumlu      155
# 79                Cayirli       30
# 81                  Payas      120
# 82      Dogansar District       50
# 87               Caglayan       25
# 88              Arabaslik        7
# 89                 Solhan      142
# 91     Karakocan district       83
# 92                Bulanik       23
# 93               Cigdemli       34
# 95         Konak District       92
# 102               Uskudar      154
# 111             Mesepinar      107
# 114               Bademli       10
# 125                 Erzin       58
# 130               Isparta       77
# 141                 Dazya       42
# 142      Kadikoy district       82
# 163                 Aydin        9
# 179             Eskisehir       60
# 188                 Tokat      148
# 190               Yenikoy      157
# 202               Pervari      122
# 206   Guclukonak District       68
# 207            Mardinkapi      104
# 212               Dortyol       52
# 221                Omerli      116
# 223             Yenisehir      159
# 224                Taskoy      146
# 228                   Mus      110
# 229        Gebze district       62
# 232               Ziyaret      164
# 233        Hozat district       74
# 235                 Cesme       32
# 236     Kusadasi district       97
# 238                 Torul      150
# 243                Pendik      121
# 244                 Servi      136
# 246             Alacakaya        3
# 248           Beytussebap       17
# 249     Islahiye district       76
# 251             Yuksekova      161
# 256               Bukardi       22
# 267                  Ordu      118
# 273              Beldeler       14
# 275             Geyiksuyu       67
# 280               Bakacak       11
# 282                 Siran      140
# 284             Gecitalan       63
# 286               Antalya        6
# 289                 Catak       29
# 294                Samsun      129
# 295   Diyarbakir district       49
# 296                  Kigi       87
# 302               Pulumur      125
# 303         Genc district       66
# 306         Kulp district       96
# 316             Ogulveren      115
# 319               Malatya      101
# 323                 Sason      133
# 326                Kabala       81
# 329               Egirmec       54
# 336              Refahiye      126
# 347             Besikduzu       16
# 353                Silopi      138
# 356                 Hatay       72
# 359       Duzici district       53
# 360                Midyat      109
# 362              Erzincan       59
# 366               Hakkari       69
# 367                Magara      100
# 370               Gecitli       64
# 376              Toroslar      149
# 379         Buca district       21
# 381      Saricam District      132
# 386     Nusaybin district      113
# 388                Silvan      139
# 390                Mersin      106
# 395                  Genc       65
# 396        Hizan district       73
# 397              Karliova       84
# 398                 Kemer       86
# 400               Kasimli       85
# 402             Kirikkale       88
# 403                Batman       12
# 405            Celtiksuyu       31
# 407                Sirnak      141
# 408                Bingol       19
# 409                 Izmit       80
# 410                 Ercis       56
# 412                Kozluk       94
# 413                Bitlis       20
# 414               Cukurca       39
# 418             Pinarbasi      123
# 421                Omurlu      117
# 425  Beytussebap district       18
# 426                 Mezra      108
# 427   Sultangazi district      143
# 432     Nazimiye district      111
# 435               Tunceli      152
# 438            Iskenderun       75
# 439              Semdinli      134
# 441               Antakya        5
# 447              Reyhanli      128
# 450             Belenoluk       15
# 454         Lice district       99
# 456                 Saray      131
# 457               Kocakoy       91
# 458               Diyadin       46
# 469        Cizre district       38
# 470               Daglica       41
# 479                Aritis        8
# 480                 Suruc      145
# 481           Ceylanpinar       33
# 483                 Adana        0
# 484                  Lice       98
# 485              Nusaybin      112
# 486                Tatvan      147
# 487             Malazgirt      102
# 488     Caldiran district       26
# 489        Ercis district       57
# 492                 Cinar       35
# 494    Yuksekova district      163
# 495                 Akcay        1
# 498               Pozanti      124
# 499         Hani district       71
# 500             Sanliurfa      130
# 501          Sur district      144
# 503             Gaziantep       61
# 507                  Hani       70
# 522              Marmaris      105
# 524                 Cizre       36
# 525                   Van      156
# 528                 Ozalp      119
# 529                 Dicle       44
# 530        Derik district       43
# 531      Cukurca district       40
# 535                 Izmir       79
# 536                Ankara        4
# 540            Diyarbakir       48
# 542               Unknown      153
# 544  Dogubeyazit district       51
# 545     Semdinli district      135
# 546              Istanbul       78

# %%
clusterX = dfkmean.loc[dfkmean['TargetNum'].isin([7, 8, 9])]
clusterY = dfkmean.loc[dfkmean['cityNum'].isin([37, 38])]
pd.merge(clusterX, clusterY, how='inner', on=['TargetNum', 'cityNum'])
# dfkmean
# Out:
#            city_x Target_type_x  cityNum  TargetNum          city_y  \
# 0  Cizre District      Military       37          8  Cizre District
#
#   Target_type_y
# 0      Military

# %%
from sklearn.cluster import KMeans
algorithm = KMeans(n_clusters = 2, init='random' )
algorithm.fit(dfkmean[['cityNum','TargetNum']])
labels2 = algorithm.labels_
centroids2 = algorithm.cluster_centers_ #Gán toạ độ trung tâm cụm
plt.clf()
plt.scatter( x = 'TargetNum' ,y = 'cityNum' , data = dfkmean[['TargetNum','cityNum']], c = labels2, s = 100 )
plt.scatter(x = centroids2[: , 0], y =  centroids2[: , 1], s = 100, c = 'red', alpha = 0.5)
plt.ylabel('city'), plt.xlabel('Target')
plt.show()
print('Toạ độ trung tâm cụm: ', centroids2)
# Out:
# Toạ độ trung tâm cụm:  [[136.73717949   8.73076923]
#  [ 56.46803069   7.57033248]]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import ndlib.models.ModelConfig as mc
import ndlib.models.epidemics as ep


from networkx.algorithms import bipartite
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
import matplotlib
from community import community_louvain
import seaborn as sns
from termcolor import colored
from networkx.algorithms.community import label_propagation_communities
from sklearn import preprocessing
from sklearn.cluster import KMeans
